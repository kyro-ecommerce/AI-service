# %% [markdown]
# # Recommendation System Offline Evaluation & Benchmark Report (Phase 3)
#
# This notebook evaluates the **Hybrid Recommendation System (Phase 2)** against the **Baseline Trending Popularity Model** using standard industrial RecSys metrics:
# - **NDCG@K** (Normalized Discounted Cumulative Gain at K)
# - **Precision@K & Recall@K**
# - **Hit Rate@K**
# - **Catalog Coverage**

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from scripts.evaluate_recsys import evaluate_recommendation_models, main

# Run Offline Evaluation Benchmark
main()
